# %% [markdown]
# <a href="https://colab.research.google.com/github/kra3810/The-Puppet-Master/blob/main/liveportrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/LivePortrait
# %cd /content/LivePortrait

# !rm -rf /content/LivePortrait/pretrained_weights
# !git clone https://huggingface.co/camenduru/LivePortrait /content/LivePortrait/pretrained_weights

# !pip install tyro==0.8.5 onnxruntime-gpu==1.18.1 onnx==1.16.1 gradio==4.36.1 colorama

# %cd /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# !python setup.py build_ext --inplace
# Out:
# /content
# fatal: destination path 'LivePortrait' already exists and is not an empty directory.
# /content/LivePortrait
# Cloning into '/content/LivePortrait/pretrained_weights'...
# remote: Enumerating objects: 19, done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 19 (from 1)
# Unpacking objects: 100% (19/19), 3.49 KiB | 1.16 MiB/s, done.
# Filtering content: 100% (8/8), 628.42 MiB | 75.99 MiB/s, done.
# ...
# /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# In file included from /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1929,
#                  from /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.12/dist-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from mesh_core_cython.cpp:1264:
# ...

# %%
# %cd /content/LivePortrait
# !python inference.py -s /content/LivePortrait/assets/examples/source/s7.jpg -d /content/LivePortrait/assets/examples/driving/d7.mp4
# Out:
# /content/LivePortrait
# [16:15:51] Load appearance_feature_extractor done.   ]8;id=777175;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=987603;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
#            Load motion_extractor done.               ]8;id=748773;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=858023;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
# [16:15:52] Load warping_module done.                 ]8;id=965937;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=57602;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
#            Load spade_generator done.                ]8;id=405428;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=304878;file:///content/LivePortrait/src/live_portrait_wrapper.py#39\39]8;;\
# ...

# %%
# !python inference.py -s /content/img.jpg -d /content/result_hd_final.mp4
# Out:
# [16:35:51] Load appearance_feature_extractor done.   ]8;id=646929;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=980457;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
#            Load motion_extractor done.               ]8;id=576668;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=393615;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
# [16:35:52] Load warping_module done.                 ]8;id=198325;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=105488;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
# [16:35:53] Load spade_generator done.                ]8;id=489664;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=493351;file:///content/LivePortrait/src/live_portrait_wrapper.py#39\39]8;;\
# ...

# %%
import os
import subprocess

# 1. ระบุชื่อไฟล์ภาพที่ถูกต้อง (เอาแบบเดี่ยวๆ ไม่เอาแบบตาราง)
# จากรูปในเครื่องคุณ ไฟล์ที่ถูกคืออันนี้ครับ
silent_video = "/content/LivePortrait/animations/img--result_hd_final.mp4"

# 2. ไฟล์เสียงต้นฉบับ (จาก Wav2Lip)
audio_source = "/content/result_hd_final.mp4"
final_output = "/content/Final_Work_With_Sound_Correct.mp4"

# เช็คว่าไฟล์มีจริงไหม
if os.path.exists(silent_video) and os.path.exists(audio_source):
    print(f"🎬 เจอภาพที่ถูกแล้ว: {silent_video}")
    print(f"🎵 เจอเสียงที่: {audio_source}")
    print("กำลังรวมร่างรอบแก้ไข... ⏳")

    # สั่งรวมภาพ + เสียง
    cmd = f'ffmpeg -y -i "{silent_video}" -i "{audio_source}" -c:v copy -c:a copy -map 0:v:0 -map 1:a:0 "{final_output}" -loglevel error'
    subprocess.call(cmd, shell=True)

    print("\n✅ เสร็จแล้วครับ! (รอบนี้หน้าเดียวเต็มจอแน่นอน)")
    print(f"👉 โหลดไฟล์นี้ได้เลย: {final_output}")
else:
    print("❌ ยังหาไฟล์ไม่เจอ... ลองเช็คชื่อไฟล์ในโฟลเดอร์ animations อีกทีครับ")
    print("ว่ามันชื่อ img--result_hd_final.mp4 หรือเปล่า?")
# Out:
# 🎬 เจอภาพที่ถูกแล้ว: /content/LivePortrait/animations/img--result_hd_final.mp4
# 🎵 เจอเสียงที่: /content/result_hd_final.mp4
# กำลังรวมร่างรอบแก้ไข... ⏳
#
# ✅ เสร็จแล้วครับ! (รอบนี้หน้าเดียวเต็มจอแน่นอน)
# 👉 โหลดไฟล์นี้ได้เลย: /content/Final_Work_With_Sound_Correct.mp4
